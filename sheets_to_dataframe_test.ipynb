# %% [markdown]
# ## Sheets to DataFrame

# %% [markdown]
# #### An experimentation notebook to validate that contents from Google Sheets can be imported over to create dataframe and create visualizations.

# %%
import pandas as pd
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from pprint import pprint
import plotly
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go
import plotly.figure_factory as ff
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
scope = ["https://spreadsheets.google.com/feeds",'https://www.googleapis.com/auth/spreadsheets',"https://www.googleapis.com/auth/drive.file","https://www.googleapis.com/auth/drive"]
creds = ServiceAccountCredentials.from_json_keyfile_name("/Users/ayush.LAPTOP-A9620OED/Downloads/creds.json", scope)
client = gspread.authorize(creds)
sheet = client.open("api_test").sheet1  # Open the spreadhseet
data = sheet.get_all_records()  # Get a list of all records

# %%
data
# Out:
# [{'name': 'dog', 'number': 3},
#  {'name': 'cat', 'number': 2},
#  {'name': 'fish', 'number': 5},
#  {'name': 'ant', 'number': 3}]

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    name  number
# 0   dog       3
# 1   cat       2
# 2  fish       5
# 3   ant       3

# %%
iplot([go.Bar(x=df.name, y=df.number)])
# Out:
# <div>
#
#
#             <div id="176a41bf-345f-4ad7-ab0a-350ed66a33ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("176a41bf-345f-4ad7-ab0a-350ed66a33ca")) {
#                     Plotly.newPlot(
#                         '176a41bf-345f-4ad7-ab0a-350ed66a33ca',
#                         [{"type": "bar", "uid": "62f8c9db-010a-49aa-84f1-e4dd4c720e3e", "x": ["dog", "cat", "fish", "ant"], "y": [3, 2, 5, 3]}],
#                         {},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('176a41bf-345f-4ad7-ab0a-350ed66a33ca');
# ...
